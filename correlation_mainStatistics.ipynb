# %%
#necessary imports
import pandas as pd

# %%
url = "https://www.basketball-reference.com/leagues/NBA_2020.html"

# %%
df = pd.read_html(url, header=0)

# %%
type(df)
# Out:
# list

# %%
df
# Out:
# [          Eastern Conference   W   L   W/L%    GB   PS/G   PA/G    SRS
#  0       Milwaukee Bucks* (1)  53  12  0.815     —  118.6  107.4  10.44
#  1       Toronto Raptors* (2)  46  18  0.719   6.5  113.0  106.5   5.88
#  2        Boston Celtics* (3)  43  21  0.672   9.5  113.0  106.8   5.69
#  3            Miami Heat* (4)  41  24  0.631  12.0  112.2  108.9   2.58
#  4        Indiana Pacers* (5)  39  26  0.600  14.0  109.3  107.4   1.61
#  5    Philadelphia 76ers* (6)  39  26  0.600  14.0  109.6  107.4   2.22
#  6          Brooklyn Nets (7)  30  34  0.469  22.5  110.8  111.4  -1.18
#  7          Orlando Magic (8)  30  35  0.462  23.0  106.4  107.3  -0.85
#  8     Washington Wizards (9)  24  40  0.375  28.5  115.6  119.7  -4.86
#  9     Charlotte Hornets (10)  23  42  0.354  30.0  102.9  109.6  -6.88
#  10        Chicago Bulls (11)  22  43  0.338  31.0  106.8  109.9  -3.81
#  11      New York Knicks (12)  21  45  0.318  32.5  105.8  112.3  -6.55
# ...

# %%
len(df)
# Out:
# 4

# %%
df[3].dtypes
# Out:
# Western Conference    object
# W                     object
# L                     object
# W/L%                  object
# GB                    object
# PS/G                  object
# PA/G                  object
# SRS                   object
# dtype: object

# %%
# 0 means the first table, 1 is the second, 2 is the third, etc.
df[3]
# Out:
#              Western Conference  ...                 SRS
# 0            Northwest Division  ...  Northwest Division
# 1           Denver Nuggets* (3)  ...                3.02
# 2                Utah Jazz* (4)  ...                3.20
# 3    Oklahoma City Thunder* (5)  ...                2.79
# 4    Portland Trail Blazers (9)  ...               -1.11
# 5   Minnesota Timberwolves (14)  ...               -3.78
# 6              Pacific Division  ...    Pacific Division
# 7       Los Angeles Lakers* (1)  ...                7.75
# 8     Los Angeles Clippers* (2)  ...                6.74
# 9         Sacramento Kings (11)  ...               -1.44
# 10            Phoenix Suns (13)  ...               -1.05
# 11   Golden State Warriors (15)  ...               -7.92
# 12           Southwest Division  ...  Southwest Division
# 13         Houston Rockets* (6)  ...                3.78
# 14         Dallas Mavericks (7)  ...                5.84
# ...

# %%
temp_df = df[3]

# %%
temp_df
# Out:
#              Western Conference  ...                 SRS
# 0            Northwest Division  ...  Northwest Division
# 1           Denver Nuggets* (3)  ...                3.02
# 2                Utah Jazz* (4)  ...                3.20
# 3    Oklahoma City Thunder* (5)  ...                2.79
# 4    Portland Trail Blazers (9)  ...               -1.11
# 5   Minnesota Timberwolves (14)  ...               -3.78
# 6              Pacific Division  ...    Pacific Division
# 7       Los Angeles Lakers* (1)  ...                7.75
# 8     Los Angeles Clippers* (2)  ...                6.74
# 9         Sacramento Kings (11)  ...               -1.44
# 10            Phoenix Suns (13)  ...               -1.05
# 11   Golden State Warriors (15)  ...               -7.92
# 12           Southwest Division  ...  Southwest Division
# 13         Houston Rockets* (6)  ...                3.78
# 14         Dallas Mavericks (7)  ...                5.84
# ...

# %%
df_west = temp_df[~temp_df["W"].str.contains("Division")]

# %%
df_west
# Out:
#              Western Conference   W   L  W/L%    GB   PS/G   PA/G    SRS
# 1           Denver Nuggets* (3)  43  22  .662     —  110.4  107.4   3.02
# 2                Utah Jazz* (4)  41  23  .641   1.5  111.0  107.9   3.20
# 3    Oklahoma City Thunder* (5)  40  24  .625   2.5  110.8  108.3   2.79
# 4    Portland Trail Blazers (9)  29  37  .439  14.5  113.6  115.2  -1.11
# 5   Minnesota Timberwolves (14)  19  45  .297  23.5  113.3  117.5  -3.78
# 7       Los Angeles Lakers* (1)  49  14  .778     —  114.3  106.9   7.75
# 8     Los Angeles Clippers* (2)  44  20  .688   5.5  116.2  109.7   6.74
# 9         Sacramento Kings (11)  28  36  .438  21.5  109.0  110.9  -1.44
# 10            Phoenix Suns (13)  26  39  .400  24.0  112.6  113.9  -1.05
# 11   Golden State Warriors (15)  15  50  .231  35.0  106.3  115.0  -7.92
# 13         Houston Rockets* (6)  40  24  .625     —  118.1  114.4   3.78
# 14         Dallas Mavericks (7)  40  27  .597   1.5  116.4  110.3   5.84
# ...

# %%
df_west.dtypes
# Out:
# Western Conference    object
# W                     object
# L                     object
# W/L%                  object
# GB                    object
# PS/G                  object
# PA/G                  object
# SRS                   object
# dtype: object

# %%
url1 = "https://en.wikipedia.org/wiki/Premier_League"

# %%
df = pd.read_html(url1 , header = 0)

# %%
df
# Out:
# [                Unnamed: 0                                         Unnamed: 1
#  0                  Founded                     20 February 1992; 28 years ago
#  1                  Country                                            England
#  2            Confederation                                               UEFA
#  3          Number of teams                                                 20
#  4         Level on pyramid                                                  1
#  5            Relegation to                                   EFL Championship
#  6          Domestic cup(s)                          FA CupFA Community Shield
#  7            League cup(s)                                            EFL Cup
#  8     International cup(s)            UEFA Champions LeagueUEFA Europa League
#  9        Current champions                    Liverpool (1st title) (2019–20)
#  10      Most championships                       Manchester United(13 titles)
# ...

# %%
len(df)
# Out:
# 35

# %%
df[6]
# Out:
#    No.   Season           Champion
# 0   21  2012–13  Manchester United
# 1   22  2013–14    Manchester City
# 2   23  2014–15            Chelsea
# 3   24  2015–16     Leicester City
# 4   25  2016–17            Chelsea
# 5   26  2017–18    Manchester City
# 6   27  2018–19    Manchester City
# 7   28  2019–20          Liverpool

# %%
type(df[6])
# Out:
# pandas.core.frame.DataFrame

# %%
df_champ = pd.concat([df[4],df[5],df[6]], axis = 0)

# %%
df_champ
# Out:
#    No.     Season           Champion
# 0    1    1992–93  Manchester United
# 1    2    1993–94  Manchester United
# 2    3    1994–95   Blackburn Rovers
# 3    4    1995–96  Manchester United
# 4    5    1996–97  Manchester United
# 5    6    1997–98            Arsenal
# 6    7    1998–99  Manchester United
# 7    8  1999–2000  Manchester United
# 8    9    2000–01  Manchester United
# 9   10    2001–02            Arsenal
# 0   11    2002–03  Manchester United
# 1   12    2003–04            Arsenal
# 2   13    2004–05            Chelsea
# 3   14    2005–06            Chelsea
# 4   15    2006–07  Manchester United
# 5   16    2007–08  Manchester United
# 6   17    2008–09  Manchester United
# 7   18    2009–10            Chelsea
# 8   19    2010–11  Manchester United
# 9   20    2011–12    Manchester City
# 0   21    2012–13  Manchester United
# 1   22    2013–14    Manchester City
# 2   23    2014–15            Chelsea
# 3   24    2015–16     Leicester City
# ...

# %%
df_champ["Champion"].value_counts()
# Out:
# Manchester United    13
# Chelsea               5
# Manchester City       4
# Arsenal               3
# Liverpool             1
# Blackburn Rovers      1
# Leicester City        1
# Name: Champion, dtype: int64

# %%
#imports
import pandas as pd
import numpy as np

# %%
url = "https://www.basketball-reference.com/leagues/NBA_2020.html"

df = pd.read_html(url, header = 0)

# %%
df
# Out:
# [          Eastern Conference   W   L   W/L%    GB   PS/G   PA/G    SRS
#  0       Milwaukee Bucks* (1)  53  12  0.815     —  118.6  107.4  10.44
#  1       Toronto Raptors* (2)  46  18  0.719   6.5  113.0  106.5   5.88
#  2        Boston Celtics* (3)  43  21  0.672   9.5  113.0  106.8   5.69
#  3            Miami Heat* (4)  41  24  0.631  12.0  112.2  108.9   2.58
#  4        Indiana Pacers* (5)  39  26  0.600  14.0  109.3  107.4   1.61
#  5    Philadelphia 76ers* (6)  39  26  0.600  14.0  109.6  107.4   2.22
#  6          Brooklyn Nets (7)  30  34  0.469  22.5  110.8  111.4  -1.18
#  7          Orlando Magic (8)  30  35  0.462  23.0  106.4  107.3  -0.85
#  8     Washington Wizards (9)  24  40  0.375  28.5  115.6  119.7  -4.86
#  9     Charlotte Hornets (10)  23  42  0.354  30.0  102.9  109.6  -6.88
#  10        Chicago Bulls (11)  22  43  0.338  31.0  106.8  109.9  -3.81
#  11      New York Knicks (12)  21  45  0.318  32.5  105.8  112.3  -6.55
# ...

# %%
len(df)
# Out:
# 4

# %%
temp_df = df[3]

# %%
temp_df
# Out:
#              Western Conference  ...                 SRS
# 0            Northwest Division  ...  Northwest Division
# 1           Denver Nuggets* (3)  ...                3.02
# 2                Utah Jazz* (4)  ...                3.20
# 3    Oklahoma City Thunder* (5)  ...                2.79
# 4    Portland Trail Blazers (9)  ...               -1.11
# 5   Minnesota Timberwolves (14)  ...               -3.78
# 6              Pacific Division  ...    Pacific Division
# 7       Los Angeles Lakers* (1)  ...                7.75
# 8     Los Angeles Clippers* (2)  ...                6.74
# 9         Sacramento Kings (11)  ...               -1.44
# 10            Phoenix Suns (13)  ...               -1.05
# 11   Golden State Warriors (15)  ...               -7.92
# 12           Southwest Division  ...  Southwest Division
# 13         Houston Rockets* (6)  ...                3.78
# 14         Dallas Mavericks (7)  ...                5.84
# ...

# %%
df_west = temp_df[~temp_df["W"].str.contains("Division")]

# %%
df = df[~df[(df['group'] == 'control') & (df['landing_page'] == "new_page")]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e317971257a2> in <module>
# ----> 1 index = df[(df['group'] == 'control') & (df['landing_page'] == new_page)]
#
# NameError: name 'df' is not defined

# %%
df_west
# Out:
#              Western Conference   W   L  W/L%    GB   PS/G   PA/G    SRS
# 1           Denver Nuggets* (3)  43  22  .662     —  110.4  107.4   3.02
# 2                Utah Jazz* (4)  41  23  .641   1.5  111.0  107.9   3.20
# 3    Oklahoma City Thunder* (5)  40  24  .625   2.5  110.8  108.3   2.79
# 4    Portland Trail Blazers (9)  29  37  .439  14.5  113.6  115.2  -1.11
# 5   Minnesota Timberwolves (14)  19  45  .297  23.5  113.3  117.5  -3.78
# 7       Los Angeles Lakers* (1)  49  14  .778     —  114.3  106.9   7.75
# 8     Los Angeles Clippers* (2)  44  20  .688   5.5  116.2  109.7   6.74
# 9         Sacramento Kings (11)  28  36  .438  21.5  109.0  110.9  -1.44
# 10            Phoenix Suns (13)  26  39  .400  24.0  112.6  113.9  -1.05
# 11   Golden State Warriors (15)  15  50  .231  35.0  106.3  115.0  -7.92
# 13         Houston Rockets* (6)  40  24  .625     —  118.1  114.4   3.78
# 14         Dallas Mavericks (7)  40  27  .597   1.5  116.4  110.3   5.84
# ...

# %%
df_west.dtypes
# Out:
# Western Conference    object
# W                     object
# L                     object
# W/L%                  object
# GB                    object
# PS/G                  object
# PA/G                  object
# SRS                   object
# dtype: object

# %%
df_west.columns
# Out:
# Index(['Western Conference', 'W', 'L', 'W/L%', 'GB', 'PS/G', 'PA/G', 'SRS'], dtype='object')

# %%
df_west[['W', 'L', 'W/L%', 'GB', 'PS/G', 'PA/G', 'SRS']] = df_west[['W', 'L', 'W/L%', 'GB', 'PS/G', 'PA/G', 'SRS']].apply(pd.to_numeric, errors = "coerce")
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df_west
# Out:
#              Western Conference   W   L   W/L%    GB   PS/G   PA/G   SRS
# 1           Denver Nuggets* (3)  43  22  0.662   NaN  110.4  107.4  3.02
# 2                Utah Jazz* (4)  41  23  0.641   1.5  111.0  107.9  3.20
# 3    Oklahoma City Thunder* (5)  40  24  0.625   2.5  110.8  108.3  2.79
# 4    Portland Trail Blazers (9)  29  37  0.439  14.5  113.6  115.2 -1.11
# 5   Minnesota Timberwolves (14)  19  45  0.297  23.5  113.3  117.5 -3.78
# 7       Los Angeles Lakers* (1)  49  14  0.778   NaN  114.3  106.9  7.75
# 8     Los Angeles Clippers* (2)  44  20  0.688   5.5  116.2  109.7  6.74
# 9         Sacramento Kings (11)  28  36  0.438  21.5  109.0  110.9 -1.44
# 10            Phoenix Suns (13)  26  39  0.400  24.0  112.6  113.9 -1.05
# 11   Golden State Warriors (15)  15  50  0.231  35.0  106.3  115.0 -7.92
# 13         Houston Rockets* (6)  40  24  0.625   NaN  118.1  114.4  3.78
# 14         Dallas Mavericks (7)  40  27  0.597   1.5  116.4  110.3  5.84
# ...

# %%
df_west.dtypes
# Out:
# Western Conference     object
# W                       int64
# L                       int64
# W/L%                  float64
# GB                    float64
# PS/G                  float64
# PA/G                  float64
# SRS                   float64
# dtype: object

# %%
df_west1 = df_west.copy()

# %%
df_west1[['W', 'L', 'W/L%', 'GB', 'PS/G', 'PA/G', 'SRS']] = df_west1[['W', 'L', 'W/L%', 'GB', 'PS/G', 'PA/G', 'SRS']].apply(pd.to_numeric, errors = "coerce")

# %%
df_west1.head(5)
# Out:
#             Western Conference   W   L   W/L%    GB   PS/G   PA/G   SRS
# 1          Denver Nuggets* (3)  43  22  0.662   NaN  110.4  107.4  3.02
# 2               Utah Jazz* (4)  41  23  0.641   1.5  111.0  107.9  3.20
# 3   Oklahoma City Thunder* (5)  40  24  0.625   2.5  110.8  108.3  2.79
# 4   Portland Trail Blazers (9)  29  37  0.439  14.5  113.6  115.2 -1.11
# 5  Minnesota Timberwolves (14)  19  45  0.297  23.5  113.3  117.5 -3.78

# %%
df_west1["W"].mean()
# Out:
# 33.4

# %%
df_west1["W"].median()
# Out:
# 32.0

# %%
df_west1["W"].std()
# Out:
# 9.847407200447668

# %%
df_west1["W"].var()
# Out:
# 96.97142857142858

# %%
df_west1.describe()
# Out:
#                W          L       W/L%  ...        PS/G        PA/G        SRS
# count  15.000000  15.000000  15.000000  ...   15.000000   15.000000  15.000000
# mean   33.400000  31.066667   0.518667  ...  112.933333  112.200000   1.057333
# std     9.847407  10.017604   0.154520  ...    3.127908    3.601785   4.211709
# min    15.000000  14.000000   0.231000  ...  106.300000  106.900000  -7.920000
# 25%    27.500000  23.500000   0.433500  ...  110.900000  109.000000  -1.160000
# 50%    32.000000  33.000000   0.492000  ...  113.200000  113.700000   0.300000
# 75%    40.500000  36.500000   0.633000  ...  115.250000  114.950000   3.490000
# max    49.000000  50.000000   0.778000  ...  118.100000  117.500000   7.750000
#
# [8 rows x 7 columns]

# %%
df_west1.corr()
# Out:
#              W         L      W/L%        GB      PS/G      PA/G       SRS
# W     1.000000 -0.994451  0.998137 -0.921506  0.413937 -0.812799  0.957124
# L    -0.994451  1.000000 -0.998884  0.917883 -0.406296  0.807107 -0.950413
# W/L%  0.998137 -0.998884  1.000000 -0.918496  0.407028 -0.812009  0.953700
# GB   -0.921506  0.917883 -0.918496  1.000000 -0.559732  0.629667 -0.883405
# PS/G  0.413937 -0.406296  0.407028 -0.559732  1.000000  0.152037  0.596563
# PA/G -0.812799  0.807107 -0.812009  0.629667  0.152037  1.000000 -0.700161
# SRS   0.957124 -0.950413  0.953700 -0.883405  0.596563 -0.700161  1.000000
